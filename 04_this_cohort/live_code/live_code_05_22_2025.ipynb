# %%
#load in our libraries
import numpy as np
import pandas as pd
from sklearn import set_config
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
set_config(transform_output="pandas")

# %%
#load in our data
penguins = pd.read_csv("dataset/penguins.csv")
penguins
# Out:
#      bill_length_mm  flipper_length_mm
# 0              39.1                181
# 1              39.5                186
# 2              40.3                195
# 3              36.7                193
# 4              39.3                190
# ..              ...                ...
# 337            55.8                207
# 338            43.5                202
# 339            49.6                193
# 340            50.8                210
# 341            50.2                198
#
# [342 rows x 2 columns]

# %%
penguins.agg(['min','max'])
# Out:
#      bill_length_mm  flipper_length_mm
# min            32.1                172
# max            59.6                231

# %%
penguins_copy = penguins.copy()

# %%
scaler = StandardScaler()
standardized_penguins = scaler.fit_transform(penguins_copy)
standardized_penguins
# Out:
#      bill_length_mm  flipper_length_mm
# 0         -0.884499          -1.418347
# 1         -0.811126          -1.062250
# 2         -0.664380          -0.421277
# 3         -1.324737          -0.563715
# 4         -0.847812          -0.777373
# ..              ...                ...
# 337        2.178824           0.433355
# 338       -0.077396           0.077258
# 339        1.041543          -0.563715
# 340        1.261662           0.647013
# 341        1.151602          -0.207619
#
# [342 rows x 2 columns]

# %%
# Scatter plot for bill_length_mm vs flipper_length_mm
plt.scatter(standardized_penguins['flipper_length_mm'], standardized_penguins['bill_length_mm'])

# Adding labels and title
plt.title('Penguin Flipper Length vs Bill Length', fontsize=14)
plt.ylabel('Bill Length (mm)', fontsize=12)
plt.xlabel('Flipper Length (mm)', fontsize=12)

# Display the plot
plt.show()

# %%
kmeans = KMeans(n_clusters = 7, n_init = 10, random_state = 123)

# %%
clusters = kmeans.fit(standardized_penguins)

# %%
standardized_penguins_with_clusters = standardized_penguins.copy()

# %%
standardized_penguins_with_clusters['Cluster'] = clusters.labels_

# %%
# Plot the clusters
plt.scatter(standardized_penguins_with_clusters['flipper_length_mm'], standardized_penguins_with_clusters['bill_length_mm'], c=standardized_penguins_with_clusters['Cluster'])
plt.xlabel('Flipper Length (mm)')
plt.ylabel('Bill Length (mm)')
plt.title('K-Means Clustering of Penguins')
plt.show()

# %%
clusters.inertia_
# Out:
# 91.46405010061788

# %%
clusters.n_iter_
# Out:
# 7

# %%
#compare different values of k

penguins_clust_ks = pd.DataFrame(columns = ["k","wssd"])

for k in range(1,11):
    elbow_kmeans = KMeans(n_clusters= k, n_init=10, random_state=123)
    elbow_kmeans.fit(standardized_penguins)
    current_k = pd.DataFrame({"k": [k] ,"wssd": [elbow_kmeans.inertia_]})
    penguins_clust_ks = pd.concat([penguins_clust_ks, current_k], ignore_index=True)

# %%
penguins_clust_ks
# Out:
#     k        wssd
# 0   1  684.000000
# 1   2  247.016625
# 2   3  157.815322
# 3   4  118.766244
# 4   5   91.464050
# 5   6   78.482556
# 6   7   66.708900
# 7   8   57.785227
# 8   9   52.921568
# 9  10   48.488581

# %%
# Create the elbow plot
plt.figure(figsize=(8, 6))
plt.plot(penguins_clust_ks['k'], penguins_clust_ks['wssd'], marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Within-Cluster Sum of Squares (WSSD)')
plt.title('Elbow Plot for K-Means Clustering')
plt.grid(True)
plt.show()

# %%
! pip install  yellowbrick
# Out:
# Collecting yellowbrick
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.6/282.6 kB 1.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from yellowbrick) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from yellowbrick) (1.24.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from yellowbrick) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from yellowbrick) (1.10.1)
# Requirement already satisfied: cycler>=0.10.0 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from scikit-learn>=1.0.0->yellowbrick) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.1.1)
# Requirement already satisfied: six>=1.5 in /Users/juliagallucci/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
# Installing collected packages: yellowbrick
# Successfully installed yellowbrick-1.5

# %%
####extra
from yellowbrick.cluster import KElbowVisualizer

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,11))
visualizer.fit(standardized_penguins)
visualizer.show()
# Out:
# /Users/juliagallucci/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/juliagallucci/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/juliagallucci/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/juliagallucci/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/juliagallucci/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/juliagallucci/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/juliagallucci/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/juliagallucci/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/juliagallucci/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/juliagallucci/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>
